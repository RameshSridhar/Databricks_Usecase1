# %% [markdown]
# # Downloading sample csv data using python API call and store it inside Databricks volume named as mobile_os_usage.csv.

# %%
import requests
url= "https://public.tableau.com/app/sample-data/mobile_os_usage.csv"
response=requests.get(url)
csv_data = response.text
dbutils.fs.put("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv",csv_data,overwrite=True)
print("File downloaded and written to the volume")
